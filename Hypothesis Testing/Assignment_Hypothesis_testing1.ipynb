# %%
import pandas as pd
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5ebf0d60-f445-4a65-be58-f160e6548b63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebf0d60-f445-4a65-be58-f160e6548b63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data1=pd.read_csv("Cutlets.csv")

# %%
data1
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %% [markdown]
# Assume Null hyposthesis as Ho: μ1 = μ2 (There is no difference in diameters of cutlets between two units).
#
# Thus Alternate hypothesis as Ha: μ1 ≠ μ2 (There is significant difference in diameters of cutlets between two units) 2 Sample 2 Tail test applicable

# %%
from scipy import stats
pvalue= stats.ttest_ind(data1['Unit A'],data1['Unit B'])[1]
# Out:
# 0.4722394724599501

# %% [markdown]
# Pvalue=0.472
# alpha=0.05
# Here Pvalue > alpha so we need to accept null hypothesis which means of mean of Unit A is equal to Unit B

# %% [markdown]
# question 2

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e2aa5fea-06ff-4987-87cb-350f0ca1e7bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2aa5fea-06ff-4987-87cb-350f0ca1e7bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data2=pd.read_csv("LabTAT.csv")

# %%
data2
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
#Anova ftest statistics: Analysis of varaince between more than 2 samples or columns
#Assume Null Hypothesis Ho as No Varaince: All samples TAT population means are same
#Thus Alternate Hypothesis Ha as It has Variance: Atleast one sample TAT population mean is different

# %%
p_value=stats.f_oneway(data2['Laboratory 1'],data2['Laboratory 2'],data2['Laboratory 3'],data2['Laboratory 4'])

# %%
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
# AS P_value<alpha(0.05)
#Accept NULL Hypothesis

# %%
# QUESTION 3

# %%
uploded=files.upload()
# Out:
#      <input type="file" id="files-26f80671-2dfe-4378-8352-7fd558cf0c79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26f80671-2dfe-4378-8352-7fd558cf0c79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data3=pd.read_csv("BuyerRatio.csv")

# %%
data3
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
#Chi2 contengency independence test
#Assume Null Hypothesis as Ho: Independence of categorical variables (male-female buyer rations are similar across regions (does not vary and are not related)
#Thus Alternate Hypothesis as Ha: Dependence of categorical variables (male-female buyer rations are NOT similar across regions (does vary and somewhat/significantly related)

# %%
# Make dimensional array
import numpy as np
obs=np.array([[50,142,131,70],[435,1523,1356,750]])
obs
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
from scipy.stats import chi2_contingency
chi2_contingency(obs)# o/p is (Chi2 stats value, p_value, df, expected obsvations)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
#p_value=0.66 > alpha=0.05
# accept null hypothesis

# %%
# Question 4

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-02f591c8-2e16-49b4-835a-a94d507c71a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02f591c8-2e16-49b4-835a-a94d507c71a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data4=pd.read_csv("Costomer+OrderForm.csv")

# %%
data4
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
data4['Phillippines'].value_counts()
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64

# %%
data4['Indonesia'].value_counts()
# Out:
# Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64

# %%
data4['Malta'].value_counts()
# Out:
# Error Free    269
# Defective      31
# Name: Malta, dtype: int64

# %%
data4['India'].value_counts()
# Out:
# Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
# Make a Contiingency table
obs=np.array([[271,267,269,280],[29,33,31,20]])
obs
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]])

# %%
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
#p_value=0.277 > alpha(0.05)
# Accept Null Hypothesis
